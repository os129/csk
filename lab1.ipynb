# %%
import pandas as pd

# %%
df = pd.read_csv('./updated.csv')
df.head()
# Out:
#    Customer_ID Gender  Transaction_ID  Quantity  Avg_Price  Delivery_Charges  \
# 0            1      M         16680.0       1.0     153.71               6.5
# 1            2      M         16696.0       2.0     122.77               6.5
# 2            3      M         16699.0       1.0      81.50               6.5
# 3            4      M         16700.0       1.0     153.71               6.5
# 4            5      M         16701.0       1.0     153.71               6.5
#
#   Coupon_Status  GST Coupon_Code Transaction_Date  Age Item Purchased  \
# 0          Used  0.1      ELEC10       2019-01-01   55         Blouse
# 1      Not Used  0.1      ELEC10       2019-01-01   19        Sweater
# 2       Clicked  0.1      ELEC10       2019-01-01   50          Jeans
# 3       Clicked  0.1      ELEC10       2019-01-01   21        Sandals
# 4       Clicked  0.1      ELEC10       2019-01-01   45         Blouse
#
#    Category       Location  Review Rating Subscription Status Payment Method  \
# ...

# %%
df['Gender'] = df['Gender'].replace({"M":"Male","F":"Female"})
data = df.rename(columns={"Gender":"gen"},inplace=True)
df['gen'].head()
# Out:
# 0    Male
# 1    Male
# 2    Male
# 3    Male
# 4    Male
# Name: gen, dtype: object

# %%
df.to_csv('new_data.csv',index=False)
