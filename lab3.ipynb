# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("./updated.csv")

plt.Figure(figsize=(8,3))
# plt.scatter(df["Customer_ID"],df["Delivery_Charges"],color="blue",alpha=0.7)
# sns.boxplot(df["Customer_ID"],color="blue")
sns.histplot(df["Customer_ID"],color="blue",bins=20)
plt.xlabel("X")
plt.ylabel("y")
plt.title("Title")
plt.show()
